# %%
from pathlib import Path
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 100)

# %%
test_df = pd.read_csv('test_set_features.csv',
                      index_col='respondent_id'
)

# %%
test_df.head()
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 26707                           1.0                   0.0
# 26708                           0.0                   0.0
# 26709                           0.0                   1.0
# 26710                           0.0                   0.0
# 26711                           1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 26707                            1.0                          1.0
# 26708                            0.0                          0.0
# 26709                            1.0                          1.0
# 26710                            0.0                          0.0
# 26711                            1.0                          1.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 26707                              0.0                    1.0
# 26708                              0.0                    0.0
# 26709                              1.0                    1.0
# 26710                              0.0                    0.0
# 26711                              1.0                    1.0
#
#                doctor_recc_h1n1  doctor_recc_seasonal  chronic_med_condition  \
# respondent_id
# 26707                       0.0                   0.0                    0.0
# 26708                       0.0                   0.0                    0.0
# 26709                       0.0                   0.0                    0.0
# 26710                       1.0                   1.0                    1.0
# 26711                       0.0                   0.0                    0.0
#
#                child_under_6_months  health_worker  health_insurance  \
# respondent_id
# 26707                           0.0            0.0               1.0
# 26708                           0.0            0.0               0.0
# 26709                           0.0            0.0               NaN
# 26710                           0.0            0.0               1.0
# 26711                           0.0            1.0               1.0
#
#                opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# respondent_id
# 26707                                  5.0                1.0
# 26708                                  4.0                1.0
# 26709                                  5.0                4.0
# 26710                                  4.0                2.0
# 26711                                  5.0                2.0
#
#                opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# respondent_id
# 26707                                  1.0                          5.0
# 26708                                  1.0                          4.0
# 26709                                  2.0                          5.0
# 26710                                  2.0                          4.0
# 26711                                  4.0                          4.0
#
#                opinion_seas_risk  opinion_seas_sick_from_vacc      age_group  \
# respondent_id
# 26707                        1.0                          1.0  35 - 44 Years
# 26708                        1.0                          1.0  18 - 34 Years
# 26709                        4.0                          4.0  55 - 64 Years
# 26710                        4.0                          2.0      65+ Years
# 26711                        4.0                          2.0  35 - 44 Years
#
#                       education      race     sex             income_poverty  \
# respondent_id
# 26707          College Graduate  Hispanic  Female                  > $75,000
# 26708                  12 Years     White    Male              Below Poverty
# 26709          College Graduate     White    Male                  > $75,000
# 26710                  12 Years     White  Female  <= $75,000, Above Poverty
# 26711                  12 Years     Black  Female  <= $75,000, Above Poverty
#
#               marital_status rent_or_own   employment_status hhs_geo_region  \
# respondent_id
# 26707            Not Married        Rent            Employed       mlyzmhmf
# 26708            Not Married        Rent            Employed       bhuqouqj
# 26709                Married         Own            Employed       lrircsnp
# 26710                Married         Own  Not in Labor Force       lrircsnp
# 26711            Not Married         Own            Employed       lzgpxyit
#
#                              census_msa  household_adults  household_children  \
# respondent_id
# 26707          MSA, Not Principle  City               1.0                 0.0
# 26708                           Non-MSA               3.0                 0.0
# 26709                           Non-MSA               1.0                 0.0
# 26710          MSA, Not Principle  City               1.0                 0.0
# 26711                           Non-MSA               0.0                 1.0
#
#               employment_industry employment_occupation
# respondent_id
# 26707                    atmlpfrs              hfxkjkmi
# 26708                    atmlpfrs              xqwwgdyp
# 26709                    nduyfdeo              pvmttkik
# 26710                         NaN                   NaN
# 26711                    fcxhlnwr              mxkfnird

# %%
print("test_df.shape", test_df.shape)
# Out:
# test_df.shape (26708, 35)

# %%
data_type = test_df.dtypes
print(data_type)
# Out:
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds      float64
# behavioral_avoidance           float64
# behavioral_face_mask           float64
# behavioral_wash_hands          float64
# behavioral_large_gatherings    float64
# behavioral_outside_home        float64
# behavioral_touch_face          float64
# doctor_recc_h1n1               float64
# doctor_recc_seasonal           float64
# chronic_med_condition          float64
# child_under_6_months           float64
# health_worker                  float64
# health_insurance               float64
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                       object
# education                       object
# race                            object
# sex                             object
# income_poverty                  object
# marital_status                  object
# rent_or_own                     object
# employment_status               object
# hhs_geo_region                  object
# census_msa                      object
# household_adults               float64
# household_children             float64
# employment_industry             object
# employment_occupation           object
# dtype: object

# %%
# Identify columns based on their data type and purpose
num_cols = test_df.select_dtypes('number').columns  # Numerical columns (e.g., age, income)
cat_cols = ['race', 'sex', 'marital_status', 'rent_or_own', 'hhs_geo_region',
            'census_msa']  # Categorical columns
ord_cols = ['age_group', 'education', 'income_poverty', 'employment_status']  # Ordinal (ordered categorical) columns

# %%
missing_percentage = (test_df.isnull().sum() / len(test_df)) * 100
print(missing_percentage)
# Out:
# h1n1_concern                    0.318257
# h1n1_knowledge                  0.456792
# behavioral_antiviral_meds       0.295792
# behavioral_avoidance            0.797514
# behavioral_face_mask            0.071140
# behavioral_wash_hands           0.149768
# behavioral_large_gatherings     0.269582
# behavioral_outside_home         0.307024
# behavioral_touch_face           0.479257
# doctor_recc_h1n1                8.087464
# doctor_recc_seasonal            8.087464
# chronic_med_condition           3.489591
# child_under_6_months            3.044032
# health_worker                   2.954171
# health_insurance               45.784035
# opinion_h1n1_vacc_effective     1.490190
# opinion_h1n1_risk               1.422795
# opinion_h1n1_sick_from_vacc     1.404074
# opinion_seas_vacc_effective     1.692377
# opinion_seas_risk               1.868354
# opinion_seas_sick_from_vacc     1.950726
# age_group                       0.000000
# education                       5.268084
# race                            0.000000
# sex                             0.000000
# income_poverty                 16.837652
# marital_status                  5.399131
# rent_or_own                     7.623184
# employment_status               5.507713
# hhs_geo_region                  0.000000
# census_msa                      0.000000
# household_adults                0.842444
# household_children              0.842444
# employment_industry            49.704208
# employment_occupation          50.269582
# dtype: float64

# %%
# Function to analyze only numerical columns
def analyze_numerical_columns(df, num_cols):
    analysis = []

    for col in num_cols:
        skewness = df[col].skew()  # Calculate skewness
        missing_pct = df[col].isnull().mean() * 100  # Calculate percentage of missing values
        if missing_pct > 0:  # Only consider columns with missing values
            recommendation = "mean" if abs(skewness) < 1 else "median"  # Choose mean or median based on skewness
            analysis.append({
                "Column": col,
                "Missing (%)": missing_pct,
                "Skewness": skewness,
                "Recommendation": recommendation
            })

    return pd.DataFrame(analysis)

# Analyze numerical columns
numerical_analysis_df = analyze_numerical_columns(test_df, num_cols)

# Save analysis to CSV or print it
numerical_analysis_df.to_csv("numerical_imputation_analysis.csv", index=False)
print(numerical_analysis_df)
# Out:
#                          Column  Missing (%)  Skewness Recommendation
# 0                  h1n1_concern     0.318257 -0.167140           mean
# 1                h1n1_knowledge     0.456792 -0.236853           mean
# 2     behavioral_antiviral_meds     0.295792  4.146944         median
# 3          behavioral_avoidance     0.797514 -1.035036         median
# 4          behavioral_face_mask     0.071140  3.392642         median
# 5         behavioral_wash_hands     0.149768 -1.720685         median
# 6   behavioral_large_gatherings     0.269582  0.622027           mean
# 7       behavioral_outside_home     0.307024  0.688643           mean
# 8         behavioral_touch_face     0.479257 -0.790333           mean
# 9              doctor_recc_h1n1     8.087464  1.333304         median
# 10         doctor_recc_seasonal     8.087464  0.706113           mean
# 11        chronic_med_condition     3.489591  0.974298           mean
# 12         child_under_6_months     3.044032  2.946455         median
# 13                health_worker     2.954171  2.468747         median
# 14             health_insurance    45.784035 -2.459520         median
# 15  opinion_h1n1_vacc_effective     1.490190 -0.908375           mean
# 16            opinion_h1n1_risk     1.422795  0.689653           mean
# 17  opinion_h1n1_sick_from_vacc     1.404074  0.645195           mean
# 18  opinion_seas_vacc_effective     1.692377 -1.288581         median
# 19            opinion_seas_risk     1.868354  0.261653           mean
# 20  opinion_seas_sick_from_vacc     1.950726  0.889517           mean
# 21             household_adults     0.842444  0.777243           mean
# 22           household_children     0.842444  1.521971         median

# %%
# Function to analyze only numerical columns
def analyze_numerical_columns(df, num_cols):
    analysis = []

    for col in num_cols:
        skewness = df[col].skew()  # Calculate skewness
        missing_pct = df[col].isnull().mean() * 100  # Calculate percentage of missing values
        if missing_pct > 0:  # Only consider columns with missing values
            recommendation = "mean" if abs(skewness) < 1 else "median"  # Choose mean or median based on skewness
            analysis.append({
                "Column": col,
                "Missing (%)": missing_pct,
                "Skewness": skewness,
                "Recommendation": recommendation
            })

    return pd.DataFrame(analysis)

# %%
# Function to impute missing values
def impute_missing_values(df, recommendations):
    for _, row in recommendations.iterrows():
        column = row['Column']
        strategy = row['Recommendation']

        if strategy == 'mean':
            df[column] = df[column].fillna(df[column].mean())
        elif strategy == 'median':
            df[column] = df[column].fillna(df[column].median())
        elif strategy == 'mode':
            df[column] = df[column].fillna(df[column].mode()[0])
    return df

new_test_df = impute_missing_values(test_df, numerical_analysis_df)
new_test_df.head()
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 26707                           1.0                   0.0
# 26708                           0.0                   0.0
# 26709                           0.0                   1.0
# 26710                           0.0                   0.0
# 26711                           1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 26707                            1.0                          1.0
# 26708                            0.0                          0.0
# 26709                            1.0                          1.0
# 26710                            0.0                          0.0
# 26711                            1.0                          1.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 26707                              0.0                    1.0
# 26708                              0.0                    0.0
# 26709                              1.0                    1.0
# 26710                              0.0                    0.0
# 26711                              1.0                    1.0
#
#                doctor_recc_h1n1  doctor_recc_seasonal  chronic_med_condition  \
# respondent_id
# 26707                       0.0                   0.0                    0.0
# 26708                       0.0                   0.0                    0.0
# 26709                       0.0                   0.0                    0.0
# 26710                       1.0                   1.0                    1.0
# 26711                       0.0                   0.0                    0.0
#
#                child_under_6_months  health_worker  health_insurance  \
# respondent_id
# 26707                           0.0            0.0               1.0
# 26708                           0.0            0.0               0.0
# 26709                           0.0            0.0               1.0
# 26710                           0.0            0.0               1.0
# 26711                           0.0            1.0               1.0
#
#                opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# respondent_id
# 26707                                  5.0                1.0
# 26708                                  4.0                1.0
# 26709                                  5.0                4.0
# 26710                                  4.0                2.0
# 26711                                  5.0                2.0
#
#                opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# respondent_id
# 26707                                  1.0                          5.0
# 26708                                  1.0                          4.0
# 26709                                  2.0                          5.0
# 26710                                  2.0                          4.0
# 26711                                  4.0                          4.0
#
#                opinion_seas_risk  opinion_seas_sick_from_vacc      age_group  \
# respondent_id
# 26707                        1.0                          1.0  35 - 44 Years
# 26708                        1.0                          1.0  18 - 34 Years
# 26709                        4.0                          4.0  55 - 64 Years
# 26710                        4.0                          2.0      65+ Years
# 26711                        4.0                          2.0  35 - 44 Years
#
#                       education      race     sex             income_poverty  \
# respondent_id
# 26707          College Graduate  Hispanic  Female                  > $75,000
# 26708                  12 Years     White    Male              Below Poverty
# 26709          College Graduate     White    Male                  > $75,000
# 26710                  12 Years     White  Female  <= $75,000, Above Poverty
# 26711                  12 Years     Black  Female  <= $75,000, Above Poverty
#
#               marital_status rent_or_own   employment_status hhs_geo_region  \
# respondent_id
# 26707            Not Married        Rent            Employed       mlyzmhmf
# 26708            Not Married        Rent            Employed       bhuqouqj
# 26709                Married         Own            Employed       lrircsnp
# 26710                Married         Own  Not in Labor Force       lrircsnp
# 26711            Not Married         Own            Employed       lzgpxyit
#
#                              census_msa  household_adults  household_children  \
# respondent_id
# 26707          MSA, Not Principle  City               1.0                 0.0
# 26708                           Non-MSA               3.0                 0.0
# 26709                           Non-MSA               1.0                 0.0
# 26710          MSA, Not Principle  City               1.0                 0.0
# 26711                           Non-MSA               0.0                 1.0
#
#               employment_industry employment_occupation
# respondent_id
# 26707                    atmlpfrs              hfxkjkmi
# 26708                    atmlpfrs              xqwwgdyp
# 26709                    nduyfdeo              pvmttkik
# 26710                         NaN                   NaN
# 26711                    fcxhlnwr              mxkfnird

# %%
# test new new missing percentage after impute missing values
new_missing_percentage = (new_test_df.isnull().sum() / len(new_test_df)) * 100
print(new_missing_percentage)
# Out:
# h1n1_concern                    0.000000
# h1n1_knowledge                  0.000000
# behavioral_antiviral_meds       0.000000
# behavioral_avoidance            0.000000
# behavioral_face_mask            0.000000
# behavioral_wash_hands           0.000000
# behavioral_large_gatherings     0.000000
# behavioral_outside_home         0.000000
# behavioral_touch_face           0.000000
# doctor_recc_h1n1                0.000000
# doctor_recc_seasonal            0.000000
# chronic_med_condition           0.000000
# child_under_6_months            0.000000
# health_worker                   0.000000
# health_insurance                0.000000
# opinion_h1n1_vacc_effective     0.000000
# opinion_h1n1_risk               0.000000
# opinion_h1n1_sick_from_vacc     0.000000
# opinion_seas_vacc_effective     0.000000
# opinion_seas_risk               0.000000
# opinion_seas_sick_from_vacc     0.000000
# age_group                       0.000000
# education                       5.268084
# race                            0.000000
# sex                             0.000000
# income_poverty                 16.837652
# marital_status                  5.399131
# rent_or_own                     7.623184
# employment_status               5.507713
# hhs_geo_region                  0.000000
# census_msa                      0.000000
# household_adults                0.000000
# household_children              0.000000
# employment_industry            49.704208
# employment_occupation          50.269582
# dtype: float64

# %%
# Drop the specified columns with high missing values
columns_to_drop = ['employment_industry', 'employment_occupation']
new_test_df = new_test_df.drop(columns=columns_to_drop)
new_test_df.head()
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 26707                           1.0                   0.0
# 26708                           0.0                   0.0
# 26709                           0.0                   1.0
# 26710                           0.0                   0.0
# 26711                           1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 26707                            1.0                          1.0
# 26708                            0.0                          0.0
# 26709                            1.0                          1.0
# 26710                            0.0                          0.0
# 26711                            1.0                          1.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 26707                              0.0                    1.0
# 26708                              0.0                    0.0
# 26709                              1.0                    1.0
# 26710                              0.0                    0.0
# 26711                              1.0                    1.0
#
#                doctor_recc_h1n1  doctor_recc_seasonal  chronic_med_condition  \
# respondent_id
# 26707                       0.0                   0.0                    0.0
# 26708                       0.0                   0.0                    0.0
# 26709                       0.0                   0.0                    0.0
# 26710                       1.0                   1.0                    1.0
# 26711                       0.0                   0.0                    0.0
#
#                child_under_6_months  health_worker  health_insurance  \
# respondent_id
# 26707                           0.0            0.0               1.0
# 26708                           0.0            0.0               0.0
# 26709                           0.0            0.0               1.0
# 26710                           0.0            0.0               1.0
# 26711                           0.0            1.0               1.0
#
#                opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# respondent_id
# 26707                                  5.0                1.0
# 26708                                  4.0                1.0
# 26709                                  5.0                4.0
# 26710                                  4.0                2.0
# 26711                                  5.0                2.0
#
#                opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# respondent_id
# 26707                                  1.0                          5.0
# 26708                                  1.0                          4.0
# 26709                                  2.0                          5.0
# 26710                                  2.0                          4.0
# 26711                                  4.0                          4.0
#
#                opinion_seas_risk  opinion_seas_sick_from_vacc      age_group  \
# respondent_id
# 26707                        1.0                          1.0  35 - 44 Years
# 26708                        1.0                          1.0  18 - 34 Years
# 26709                        4.0                          4.0  55 - 64 Years
# 26710                        4.0                          2.0      65+ Years
# 26711                        4.0                          2.0  35 - 44 Years
#
#                       education      race     sex             income_poverty  \
# respondent_id
# 26707          College Graduate  Hispanic  Female                  > $75,000
# 26708                  12 Years     White    Male              Below Poverty
# 26709          College Graduate     White    Male                  > $75,000
# 26710                  12 Years     White  Female  <= $75,000, Above Poverty
# 26711                  12 Years     Black  Female  <= $75,000, Above Poverty
#
#               marital_status rent_or_own   employment_status hhs_geo_region  \
# respondent_id
# 26707            Not Married        Rent            Employed       mlyzmhmf
# 26708            Not Married        Rent            Employed       bhuqouqj
# 26709                Married         Own            Employed       lrircsnp
# 26710                Married         Own  Not in Labor Force       lrircsnp
# 26711            Not Married         Own            Employed       lzgpxyit
#
#                              census_msa  household_adults  household_children
# respondent_id
# 26707          MSA, Not Principle  City               1.0                 0.0
# 26708                           Non-MSA               3.0                 0.0
# 26709                           Non-MSA               1.0                 0.0
# 26710          MSA, Not Principle  City               1.0                 0.0
# 26711                           Non-MSA               0.0                 1.0

# %%
# Fill missing values for categorical columns
for col in cat_cols:
    new_test_df[col] = new_test_df[col].fillna('missing')

# %%
# Apply one-hot encoding to categorical columns
new_test_df = pd.get_dummies(new_test_df, columns=cat_cols, drop_first=True)

# %%
# Define ordinal mappings
ordinal_mappings = {
    'age_group': {
        '18 - 34 Years': 1,
        '35 - 44 Years': 2,
        '45 - 54 Years': 3,
        '55 - 64 Years': 4,
        '65+ Years': 5,
        'missing': None  # Assign None for missing values to handle later
    },
    'education': {
        '< 12 Years': 1,
        '12 Years': 2,
        'Some College': 3,
        'College Graduate': 4,
        'missing': None  # Assign None for missing values to handle later
    },
    'income_poverty': {
        'Below Poverty': 1,
        '<= $75,000, Above Poverty': 2,
        '> $75,000': 3,
        'missing': None  # Assign None for missing values to handle later
    },
    'employment_status': {
        'Unemployed': 1,
        'Employed': 2,
        'Not in Labor Force': 3,
        'missing': None  # Assign None for missing values to handle later
    }
}

# %%
# Map ordinal columns to numeric values and fill missing values with the median
for col, mapping in ordinal_mappings.items():
    # Map ordinal categories to numeric
    new_test_df[col] = new_test_df[col].map(mapping)

    # Fill missing values with the median rank
    new_test_df[col] = new_test_df[col].fillna(new_test_df[col].median())

# %%
# Verify the results: Check if any missing values remain
print("After processing:")
print(new_test_df.isnull().sum())  # Ensure no missing values remain
# Out:
# After processing:
# h1n1_concern                      0
# h1n1_knowledge                    0
# behavioral_antiviral_meds         0
# behavioral_avoidance              0
# behavioral_face_mask              0
# behavioral_wash_hands             0
# behavioral_large_gatherings       0
# behavioral_outside_home           0
# behavioral_touch_face             0
# doctor_recc_h1n1                  0
# doctor_recc_seasonal              0
# chronic_med_condition             0
# child_under_6_months              0
# health_worker                     0
# health_insurance                  0
# opinion_h1n1_vacc_effective       0
# opinion_h1n1_risk                 0
# opinion_h1n1_sick_from_vacc       0
# opinion_seas_vacc_effective       0
# opinion_seas_risk                 0
# opinion_seas_sick_from_vacc       0
# age_group                         0
# education                         0
# income_poverty                    0
# employment_status                 0
# household_adults                  0
# household_children                0
# race_Hispanic                     0
# race_Other or Multiple            0
# race_White                        0
# sex_Male                          0
# marital_status_Not Married        0
# marital_status_missing            0
# rent_or_own_Rent                  0
# rent_or_own_missing               0
# hhs_geo_region_bhuqouqj           0
# hhs_geo_region_dqpwygqj           0
# hhs_geo_region_fpwskwrf           0
# hhs_geo_region_kbazzjca           0
# hhs_geo_region_lrircsnp           0
# hhs_geo_region_lzgpxyit           0
# hhs_geo_region_mlyzmhmf           0
# hhs_geo_region_oxchjgsf           0
# hhs_geo_region_qufhixun           0
# census_msa_MSA, Principle City    0
# census_msa_Non-MSA                0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# Define numerical columns
numeric_cols = [
    # Behavioral factors
    'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask',
    'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home',
    'behavioral_touch_face',

    # Doctor recommendations
    'doctor_recc_h1n1', 'doctor_recc_seasonal',

    # Health-related factors
    'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance',

    # Opinions on vaccines
    'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk', 'opinion_h1n1_sick_from_vacc',
    'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc',

    # Concerns and knowledge
    'h1n1_concern', 'h1n1_knowledge',

    # Ordinal data
    'age_group', 'education', 'income_poverty', 'employment_status',

    # Household demographics
    'household_adults', 'household_children'
]

# %%
# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Scale only numeric columns
new_test_df[numeric_cols] = scaler.fit_transform(new_test_df[numeric_cols])

# %%
new_test_df.describe()
# Out:
#        h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# count  26708.000000    26708.000000               26708.000000
# mean       0.541048        0.633021                   0.049498
# std        0.300439        0.307104                   0.216910
# min        0.000000        0.000000                   0.000000
# 25%        0.333333        0.500000                   0.000000
# 50%        0.666667        0.500000                   0.000000
# 75%        0.666667        1.000000                   0.000000
# max        1.000000        1.000000                   1.000000
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# count          26708.000000           26708.00000           26708.000000
# mean               0.731953               0.06923               0.826344
# std                0.442951               0.25385               0.378820
# min                0.000000               0.00000               0.000000
# 25%                0.000000               0.00000               1.000000
# 50%                1.000000               0.00000               1.000000
# 75%                1.000000               0.00000               1.000000
# max                1.000000               1.00000               1.000000
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# count                 26708.000000             26708.000000
# mean                      0.351517                 0.337227
# std                       0.476809                 0.472046
# min                       0.000000                 0.000000
# 25%                       0.000000                 0.000000
# 50%                       0.000000                 0.000000
# 75%                       1.000000                 1.000000
# max                       1.000000                 1.000000
#
#        behavioral_touch_face  doctor_recc_h1n1  doctor_recc_seasonal  \
# count           26708.000000      26708.000000          26708.000000
# mean                0.683747          0.204658              0.333551
# std                 0.463906          0.403459              0.452022
# min                 0.000000          0.000000              0.000000
# 25%                 0.000000          0.000000              0.000000
# 50%                 1.000000          0.000000              0.000000
# 75%                 1.000000          0.000000              1.000000
# max                 1.000000          1.000000              1.000000
#
#        chronic_med_condition  child_under_6_months  health_worker  \
# count           26708.000000          26708.000000   26708.000000
# mean                0.281037              0.083683       0.108207
# std                 0.441601              0.276917       0.310648
# min                 0.000000              0.000000       0.000000
# 25%                 0.000000              0.000000       0.000000
# 50%                 0.000000              0.000000       0.000000
# 75%                 1.000000              0.000000       0.000000
# max                 1.000000              1.000000       1.000000
#
#        health_insurance  opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# count      26708.000000                 26708.000000       26708.000000
# mean           0.939232                     0.711155           0.331710
# std            0.238909                     0.250008           0.316632
# min            0.000000                     0.000000           0.000000
# 25%            1.000000                     0.500000           0.000000
# 50%            1.000000                     0.750000           0.250000
# 75%            1.000000                     1.000000           0.750000
# max            1.000000                     1.000000           1.000000
#
#        opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# count                 26708.000000                 26708.000000
# mean                      0.340153                     0.756103
# std                       0.337459                     0.268501
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.750000
# 50%                       0.250000                     0.750000
# 75%                       0.750000                     1.000000
# max                       1.000000                     1.000000
#
#        opinion_seas_risk  opinion_seas_sick_from_vacc     age_group  \
# count       26708.000000                 26708.000000  26708.000000
# mean            0.427172                     0.285848      0.542375
# std             0.340782                     0.331494      0.363751
# min             0.000000                     0.000000      0.000000
# 25%             0.250000                     0.000000      0.250000
# 50%             0.250000                     0.250000      0.500000
# 75%             0.750000                     0.750000      1.000000
# max             1.000000                     1.000000      1.000000
#
#           education  income_poverty  employment_status  household_adults  \
# count  26708.000000    26708.000000       26708.000000      26708.000000
# mean       0.664358        0.580313           0.660607          0.298103
# std        0.323970        0.286144           0.287814          0.250353
# min        0.000000        0.000000           0.000000          0.000000
# 25%        0.333333        0.500000           0.500000          0.000000
# 50%        0.666667        0.500000           0.500000          0.333333
# 75%        1.000000        1.000000           1.000000          0.333333
# max        1.000000        1.000000           1.000000          1.000000
#
#        household_children
# count        26708.000000
# mean             0.179721
# std              0.310812
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.333333
# max              1.000000

# %%
new_test_df.head()
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707              0.666667             1.0                        0.0
# 26708              0.333333             0.5                        0.0
# 26709              0.666667             1.0                        0.0
# 26710              0.333333             0.5                        0.0
# 26711              1.000000             0.5                        1.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 26707                           1.0                   0.0
# 26708                           0.0                   0.0
# 26709                           0.0                   1.0
# 26710                           0.0                   0.0
# 26711                           1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 26707                            1.0                          1.0
# 26708                            0.0                          0.0
# 26709                            1.0                          1.0
# 26710                            0.0                          0.0
# 26711                            1.0                          1.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 26707                              0.0                    1.0
# 26708                              0.0                    0.0
# 26709                              1.0                    1.0
# 26710                              0.0                    0.0
# 26711                              1.0                    1.0
#
#                doctor_recc_h1n1  doctor_recc_seasonal  chronic_med_condition  \
# respondent_id
# 26707                       0.0                   0.0                    0.0
# 26708                       0.0                   0.0                    0.0
# 26709                       0.0                   0.0                    0.0
# 26710                       1.0                   1.0                    1.0
# 26711                       0.0                   0.0                    0.0
#
#                child_under_6_months  health_worker  health_insurance  \
# respondent_id
# 26707                           0.0            0.0               1.0
# 26708                           0.0            0.0               0.0
# 26709                           0.0            0.0               1.0
# 26710                           0.0            0.0               1.0
# 26711                           0.0            1.0               1.0
#
#                opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# respondent_id
# 26707                                 1.00               0.00
# 26708                                 0.75               0.00
# 26709                                 1.00               0.75
# 26710                                 0.75               0.25
# 26711                                 1.00               0.25
#
#                opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# respondent_id
# 26707                                 0.00                         1.00
# 26708                                 0.00                         0.75
# 26709                                 0.25                         1.00
# 26710                                 0.25                         0.75
# 26711                                 0.75                         0.75
#
#                opinion_seas_risk  opinion_seas_sick_from_vacc  age_group  \
# respondent_id
# 26707                       0.00                         0.00       0.25
# 26708                       0.00                         0.00       0.00
# 26709                       0.75                         0.75       0.75
# 26710                       0.75                         0.25       1.00
# 26711                       0.75                         0.25       0.25
#
#                education  income_poverty  employment_status  household_adults  \
# respondent_id
# 26707           1.000000             1.0                0.5          0.333333
# 26708           0.333333             0.0                0.5          1.000000
# 26709           1.000000             1.0                0.5          0.333333
# 26710           0.333333             0.5                1.0          0.333333
# 26711           0.333333             0.5                0.5          0.000000
#
#                household_children  race_Hispanic  race_Other or Multiple  \
# respondent_id
# 26707                    0.000000           True                   False
# 26708                    0.000000          False                   False
# 26709                    0.000000          False                   False
# 26710                    0.000000          False                   False
# 26711                    0.333333          False                   False
#
#                race_White  sex_Male  marital_status_Not Married  \
# respondent_id
# 26707               False     False                        True
# 26708                True      True                        True
# 26709                True      True                       False
# 26710                True     False                       False
# 26711               False     False                        True
#
#                marital_status_missing  rent_or_own_Rent  rent_or_own_missing  \
# respondent_id
# 26707                           False              True                False
# 26708                           False              True                False
# 26709                           False             False                False
# 26710                           False             False                False
# 26711                           False             False                False
#
#                hhs_geo_region_bhuqouqj  hhs_geo_region_dqpwygqj  \
# respondent_id
# 26707                            False                    False
# 26708                             True                    False
# 26709                            False                    False
# 26710                            False                    False
# 26711                            False                    False
#
#                hhs_geo_region_fpwskwrf  hhs_geo_region_kbazzjca  \
# respondent_id
# 26707                            False                    False
# 26708                            False                    False
# 26709                            False                    False
# 26710                            False                    False
# 26711                            False                    False
#
#                hhs_geo_region_lrircsnp  hhs_geo_region_lzgpxyit  \
# respondent_id
# 26707                            False                    False
# 26708                            False                    False
# 26709                             True                    False
# 26710                             True                    False
# 26711                            False                     True
#
#                hhs_geo_region_mlyzmhmf  hhs_geo_region_oxchjgsf  \
# respondent_id
# 26707                             True                    False
# 26708                            False                    False
# 26709                            False                    False
# 26710                            False                    False
# 26711                            False                    False
#
#                hhs_geo_region_qufhixun  census_msa_MSA, Principle City  \
# respondent_id
# 26707                            False                           False
# 26708                            False                           False
# 26709                            False                           False
# 26710                            False                           False
# 26711                            False                           False
#
#                census_msa_Non-MSA
# respondent_id
# 26707                       False
# 26708                        True
# 26709                        True
# 26710                       False
# 26711                        True

# %%
# Save joined_df to a CSV file
new_test_df.to_csv('new_test_df.csv', index=True)  # Save with index included
