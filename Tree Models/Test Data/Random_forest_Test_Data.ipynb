# %% [markdown]
# # **Loading the data**

# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
features_df = pd.read_csv('test_set_features.csv',
                      index_col='respondent_id'
)

# %%
print("features_df.shape", features_df.shape)
features_df.head()
# Out:
# features_df.shape (26708, 35)
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 26707                           1.0                   0.0
# 26708                           0.0                   0.0
# 26709                           0.0                   1.0
# 26710                           0.0                   0.0
# 26711                           1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# ...

# %%
features_df.dtypes
# Out:
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds      float64
# behavioral_avoidance           float64
# behavioral_face_mask           float64
# behavioral_wash_hands          float64
# behavioral_large_gatherings    float64
# behavioral_outside_home        float64
# behavioral_touch_face          float64
# doctor_recc_h1n1               float64
# doctor_recc_seasonal           float64
# chronic_med_condition          float64
# child_under_6_months           float64
# health_worker                  float64
# health_insurance               float64
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                       object
# education                       object
# race                            object
# ...

# %%
print(features_df.columns)
# Out:
# Index(['h1n1_concern', 'h1n1_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
#        'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'race', 'sex', 'income_poverty', 'marital_status',
#        'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa',
#        'household_adults', 'household_children', 'employment_industry',
#        'employment_occupation'],
#       dtype='object')

# %%
# Drop specified columns
columns_to_drop = ['employment_occupation', 'employment_industry', 'health_insurance']
features_df = features_df.drop(columns=columns_to_drop, errors='ignore')

# %%
# Binary replacements
features_df['sex'] = features_df['sex'].replace({'Male': 0, 'Female': 1})
features_df['marital_status'] = features_df['marital_status'].replace({'Not Married': 0, 'Married': 1})
features_df['rent_or_own'] = features_df['rent_or_own'].replace({'Rent': 0, 'Own': 1})
# Out:
# <ipython-input-16-3827df99ffa9>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features_df['sex'] = features_df['sex'].replace({'Male': 0, 'Female': 1})
# <ipython-input-16-3827df99ffa9>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features_df['marital_status'] = features_df['marital_status'].replace({'Not Married': 0, 'Married': 1})
# ...

# %%
# Ordinal mappings
features_df['age_group'] = features_df['age_group'].replace({
    '18 - 34 Years': 0, '35 - 44 Years': 1, '45 - 54 Years': 2,
    '55 - 64 Years': 3, '65+ Years': 4
})
features_df['education'] = features_df['education'].replace({
    '< 12 Years': 0, '12 Years': 1, 'Some College': 2, 'College Graduate': 3
})
features_df['income_poverty'] = features_df['income_poverty'].replace({
    'Below Poverty': 0, '<= $75,000, Above Poverty': 1, '> $75,000': 2
})
features_df['employment_status'] = features_df['employment_status'].replace({
    'Not in Labor Force': 0, 'Unemployed': 1, 'Employed': 2
})
features_df['census_msa'] = features_df['census_msa'].replace({
    'Non-MSA': 0, 'MSA, Not Principle  City': 1, 'MSA, Principle City': 2
})
# Out:
# <ipython-input-17-3e7d2c8295f5>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features_df['age_group'] = features_df['age_group'].replace({
# <ipython-input-17-3e7d2c8295f5>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features_df['education'] = features_df['education'].replace({
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# Columns to encode
columns_to_encode = ['race', 'hhs_geo_region']

# Initialize the encoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')  # Updated argument

# Fit and transform the selected columns
encoded_columns = encoder.fit_transform(features_df[columns_to_encode])

# Create a DataFrame for the encoded columns
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(columns_to_encode), index=features_df.index)

# Concatenate the encoded columns with the original dataset
features_df = pd.concat([features_df, encoded_df], axis=1)

# Drop the original columns that were one-hot encoded
features_df = features_df.drop(columns=columns_to_encode, errors='ignore')

# %%
num_cols = features_df.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    features_df[col] = features_df[col].fillna(features_df[col].median())

# %%
cat_cols = features_df.select_dtypes(include=['object']).columns
for col in cat_cols:
    features_df[col] = features_df[col].fillna('missing')

# %%
# Check for missing values
print(features_df.isnull().sum().sum())
# Out:
# 0

# %%
features_df
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
# ...                     ...             ...                        ...
# 53410                   1.0             1.0                        0.0
# 53411                   3.0             1.0                        0.0
# 53412                   0.0             1.0                        0.0
# 53413                   3.0             1.0                        0.0
# 53414                   2.0             1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
features_df.dtypes
# Out:
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds      float64
# behavioral_avoidance           float64
# behavioral_face_mask           float64
# behavioral_wash_hands          float64
# behavioral_large_gatherings    float64
# behavioral_outside_home        float64
# behavioral_touch_face          float64
# doctor_recc_h1n1               float64
# doctor_recc_seasonal           float64
# chronic_med_condition          float64
# child_under_6_months           float64
# health_worker                  float64
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                        int64
# education                      float64
# sex                              int64
# income_poverty                 float64
# ...

# %%
# Save joined_df to a CSV file
features_df.to_csv('treemodel_test_data.csv', index=True)  # Save with index included

# %%
features_df
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                   2.0             2.0                        0.0
# 26708                   1.0             1.0                        0.0
# 26709                   2.0             2.0                        0.0
# 26710                   1.0             1.0                        0.0
# 26711                   3.0             1.0                        1.0
# ...                     ...             ...                        ...
# 53410                   1.0             1.0                        0.0
# 53411                   3.0             1.0                        0.0
# 53412                   0.0             1.0                        0.0
# 53413                   3.0             1.0                        0.0
# 53414                   2.0             1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...
